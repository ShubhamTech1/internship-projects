# %%
# !python3 -m pip install paddlepaddle-gpu

# %%
import cv2

# %%
# !pip install "paddleocr>=2.0.1"

# %%
from paddleocr import PaddleOCR

# %%
ocr = PaddleOCR(lang='en')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:16<00:00, 237kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:08<00:00, 1.15MiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:15<00:00, 141kiB/s]
# ...

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=False)
# Out:
# [2024/01/09 10:23:13] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path
# ...

# %%
img_path ='/content/drive/MyDrive/SECONDARY DATA/Invoice1.jpeg'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
result = ocr.ocr(img_path, cls=True)
# Out:
# [2024/01/09 10:24:19] ppocr DEBUG: dt_boxes num : 61, elapsed : 0.3381941318511963
# [2024/01/09 10:24:20] ppocr DEBUG: cls num  : 61, elapsed : 0.17264199256896973
# [2024/01/09 10:24:22] ppocr DEBUG: rec_res num  : 61, elapsed : 2.4927024841308594

# %%
print(result)
# Out:
# [[[[[785.0, 75.0], [899.0, 79.0], [898.0, 104.0], [784.0, 100.0]], ('TAX INVOI', 0.965408980846405)], [[[293.0, 102.0], [582.0, 102.0], [582.0, 125.0], [293.0, 125.0]], ('AVENUE SUPERMARTS LTD', 0.9563154578208923)], [[[785.0, 110.0], [882.0, 114.0], [881.0, 137.0], [784.0, 133.0]], ('Invoice No.', 0.9576103687286377)], [[[237.0, 127.0], [612.0, 130.0], [612.0, 158.0], [236.0, 155.0]], ('CIN:L51900MH2000PLC126473', 0.9701728224754333)], [[[786.0, 138.0], [895.0, 142.0], [895.0, 165.0], [786.0, 161.0]], ('Invoice Date', 0.9594194293022156)], [[[263.0, 160.0], [582.0, 163.0], [582.0, 187.0], [263.0, 183.0]], ('GSTIN36AACCA8432H1ZR', 0.9854373931884766)], [[[247.0, 187.0], [599.0, 192.0], [599.0, 220.0], [246.0, 215.0]], ('FSSAI No13620011000658', 0.9680678844451904)], [[[794.0, 203.0], [890.0, 203.0], [890.0, 227.0], [794.0, 227.0]], ('SHIP TO', 0.9500875473022461)], [[[792.0, 238.0], [899.0, 238.0], [899.0, 262.0], [792.0, 262.0]], ('TRIDDYSIN', 0.9917858839035034)], [[[286.0, 248.0],
# ...

# %%
folder_path = '/content/drive/MyDrive/SECONDARY DATA'

# %%
import glob

# %%
image_paths = glob.glob(folder_path + '/*.jpeg')

# %%
num_rows = 4
num_cols = 4

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 10))

# %%
for i, image_path in enumerate(image_paths):
    row = i // num_cols
    col = i % num_cols

    img = mpimg.imread(image_path)
    axes[row, col].imshow(img)
    axes[row, col].axis('off')

# %%
plt.tight_layout()

# %%
plt.show()

# %%
ocr = PaddleOCR()
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/chinese/ch_PP-OCRv4_det_infer.tar to /root/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer/ch_PP-OCRv4_det_infer.tar
# 100%|██████████| 4.89M/4.89M [00:17<00:00, 279kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/chinese/ch_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer/ch_PP-OCRv4_rec_infer.tar
# 100%|██████████| 11.0M/11.0M [00:11<00:00, 952kiB/s]
# ...

# %%
image_dir = '/content/drive/MyDrive/SECONDARY DATA'

# %%
results = []

# %%
import os

# %%
# !pip install opencv-python

# %%
import cv2

for filename in os.listdir(image_dir):
    if filename.endswith(".jpeg"):
        image_path = os.path.join(image_dir, filename)

        # Read the image using OpenCV
        image = cv2.imread(image_path)

        # Perform OCR on the image using PaddleOCR
        result = ocr.ocr(image)

        # Store the result in the list
        results.append((filename, result))
# Out:
# [2024/01/09 10:26:11] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/01/09 10:26:12] ppocr DEBUG: dt_boxes num : 62, elapsed : 1.6169171333312988
# [2024/01/09 10:26:13] ppocr DEBUG: rec_res num  : 62, elapsed : 0.7097108364105225
# [2024/01/09 10:26:13] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/01/09 10:26:13] ppocr DEBUG: dt_boxes num : 88, elapsed : 0.110748291015625
# [2024/01/09 10:26:14] ppocr DEBUG: rec_res num  : 88, elapsed : 0.5029764175415039
# [2024/01/09 10:26:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/01/09 10:26:14] ppocr DEBUG: dt_boxes num : 102, elapsed : 0.10467100143432617
# [2024/01/09 10:26:14] ppocr DEBUG: rec_res num  : 102, elapsed : 0.40108609199523926
# ...

# %%
for filename, result in results:
    print(f"Text in {filename}:")
    for line in result:
        for word in line:
            print(word[1][0], end=' ')
        print()
    print()
# Out:
# Text in Invoice1.jpeg:
# TAXINVOIO AVENUE SUPERMARTS LTD InvoiceNo CIN:L51900MH2000PLC126473 Invoice Date GSTIN:36AACCA8432H1ZR FSSAI No :13620011000658 SHIP TO DMART HIMAYATHNAGAR TRIDDYSIN H.NO.3-6-288/4$5 OPP OID MLA QUARTERS BESIDE TOYATA SHOWROOM HYDERGUDA BASHERBAGH ROAD MRP RA HYDERABAD 500029 243 187 Phone :040-23298560 TAX INVOICE Bi11 No:501802014-012959 Bi1l Dt: 03/02/2023 Vou. :S138014-0242 Cashier:ANT/138322 Time :12:55PM HSN Particular Qty/Kg Rate Value 1CGST@ 0.00% SGST@ 0.00% 2501.00 AASHIR-1kg 26.32 52.64 2 CGST@ 9.00% SGST@ 9.00% 330499 NIVE-400ml 510.00 Items: 2 Qty: 562.64 <--GST Breaku (Amount INR) GST Taxable SGST CESS Total IND Amount Amount 1 52.64 52.64 2 432.2038.90 38.90 510.00 484.8438.90 38.90 562.64 Amount Recd From Customer --> 562.64
#
# Text in Invoice10.jpeg:
# ...

# %%
text = []
for filename, result in results:
    print(f"Text in {filename}:")
    for line in result:
        for word in line:
            print(word[1][0], end='\n')
            text.append(word[1][0])
        print()
    print()
# Out:
# Text in Invoice1.jpeg:
# TAXINVOIO
# AVENUE SUPERMARTS LTD
# InvoiceNo
# CIN:L51900MH2000PLC126473
# Invoice Date
# GSTIN:36AACCA8432H1ZR
# FSSAI No :13620011000658
# SHIP TO
# DMART HIMAYATHNAGAR
# TRIDDYSIN
# H.NO.3-6-288/4$5
# OPP OID MLA QUARTERS
# BESIDE TOYATA SHOWROOM
# HYDERGUDA BASHERBAGH ROAD
# MRP
# RA
# HYDERABAD 500029
# 243
# 187
# Phone :040-23298560
# TAX INVOICE
# Bi11 No:501802014-012959
# Bi1l Dt: 03/02/2023 Vou. :S138014-0242
# Cashier:ANT/138322
# Time :12:55PM
# HSN
# Particular Qty/Kg
# Rate
# Value
# 1CGST@ 0.00% SGST@ 0.00%
# 2501.00 AASHIR-1kg
# 26.32
# 52.64
# 2 CGST@ 9.00% SGST@ 9.00%
# 330499 NIVE-400ml
# 510.00
# Items:
# 2 Qty:
# 562.64
# <--GST Breaku
# (Amount INR)
# GST Taxable
# SGST
# CESS
# Total
# IND Amount
# Amount
# 1
# 52.64
# 52.64
# 2
# 432.2038.90
# 38.90
# 510.00
# 484.8438.90
# 38.90
# 562.64
# Amount Recd From Customer -->
# 562.64
#
#
# Text in Invoice10.jpeg:
# DMart
# AVENUE SUPERHARTS LTO
# CIN :-L51900MH2000PLC126473
# ...

# %%
# Process the stored results
boxes = []
for filename, result in results:
    print(f"Text in {filename}:")
    for line in result:
        for word in line:
            print(word[0], end='\n ')
            boxes.append(word[0])
        print()
    print()
# Out:
# Text in Invoice1.jpeg:
# [[783.0, 77.0], [899.0, 77.0], [899.0, 105.0], [783.0, 105.0]]
#  [[293.0, 100.0], [584.0, 100.0], [584.0, 128.0], [293.0, 128.0]]
#  [[788.0, 115.0], [878.0, 115.0], [878.0, 133.0], [788.0, 133.0]]
#  [[235.0, 127.0], [612.0, 132.0], [612.0, 160.0], [235.0, 155.0]]
#  [[787.0, 138.0], [894.0, 144.0], [893.0, 167.0], [785.0, 161.0]]
#  [[262.0, 158.0], [586.0, 162.0], [585.0, 190.0], [261.0, 187.0]]
#  [[245.0, 185.0], [601.0, 190.0], [600.0, 224.0], [245.0, 218.0]]
#  [[795.0, 200.0], [889.0, 204.0], [888.0, 229.0], [794.0, 225.0]]
#  [[287.0, 248.0], [558.0, 254.0], [557.0, 282.0], [286.0, 276.0]]
#  [[792.0, 240.0], [898.0, 240.0], [898.0, 263.0], [792.0, 263.0]]
#  [[297.0, 278.0], [558.0, 287.0], [557.0, 317.0], [296.0, 308.0]]
#  [[283.0, 310.0], [571.0, 319.0], [570.0, 347.0], [283.0, 338.0]]
#  [[269.0, 340.0], [588.0, 350.0], [587.0, 379.0], [268.0, 368.0]]
#  [[237.0, 368.0], [603.0, 382.0], [601.0, 415.0], [236.0, 401.0]]
# ...

# %%
score = []

for filename, result in results:
    print(f"Text in {filename}:")
    for line in result:
        for word in line:
            print(word[1][1], end='\n ')
            score.append(word[1][1])
        print()
    print()
# Out:
# Text in Invoice1.jpeg:
# 0.9346117377281189
#  0.9589073657989502
#  0.9826694130897522
#  0.9912440776824951
#  0.9586285948753357
#  0.9832836985588074
#  0.9691398739814758
#  0.9192631840705872
#  0.966930091381073
#  0.991241455078125
#  0.9857907891273499
#  0.9697974920272827
#  0.9670153260231018
#  0.9672446250915527
#  0.970430850982666
#  0.9936075210571289
#  0.9647385478019714
#  0.9988806247711182
#  0.938610315322876
#  0.9578031301498413
#  0.9738771319389343
#  0.9361642003059387
#  0.9280511736869812
#  0.9887909293174744
#  0.8707548379898071
#  0.996260404586792
#  0.9545978307723999
#  0.9879192113876343
#  0.9767147898674011
#  0.9464243054389954
#  0.9617598056793213
#  0.9990955591201782
#  0.9993613958358765
#  0.9585703015327454
#  0.9675259590148926
#  0.9979779124259949
#  0.9961423873901367
#  0.9004581570625305
#  0.9979502558708191
#  0.9454634785652161
#  0.9847109913825989
#  0.9831588864326477
#  0.9938506484031677
#  0.9920517802238464
# ...

# %%
font_path = os.path.join('PaddleOCR','doc','fonts','latinitalic.ttf')

# %%
import numpy as np
from paddleocr import PaddleOCR,draw_ocr

# %%
# image view with bounding boxes
plt.figure(figsize=(300,140))
annotated = draw_ocr(image, boxes, text, score, font_path = '/content/latinitalic.ttf')
plt.imshow(annotated)

# %%
import pandas as pd
import re

# %%
df1 = pd.DataFrame(columns=['Bill_Date', 'Bill_No', 'Bill_Product', 'Bill_Quantity', 'Price'])
bill_no = None
bill_date = None

# %%
for i in range(len(text)):
    item = text[i]

    # Match bill number

    match_bill_no = re.search(r"\d{9}-\d{1,6}", item)
    if match_bill_no:
        bill_no = match_bill_no.group()
        print("Bill Number:", bill_no)

    # Match bill date

    match_bill_date = re.search(r"\d{2}/\d{2}/\d{4}", item)
    if match_bill_date:
        bill_date = match_bill_date.group()
        print("Bill Date:", bill_date)

    # Match product name
    match_product = re.search(r"\s[A-Z]+\s[A-Z0-9]+\s[A-Z]+-\d[a-zA-Z]+|\s[A-Z]+\s[A-Z]+\s[A-Z]+-\d[a-zA-Z]+|[a-zA-Z]+[]\s\d+-[a-zA-Z]+\d[a-z]+|[a-aA-Z]+\s[a-zA-z]+\s+[a-zA-z]+\s\d+[a-zA-z]|[A-Z]+-\d+[a-zA-Z]|[A-z]+\s[A-Z]+-[a-zA-Z]+", item)
    if match_product:
        product_name = match_product.group()
        print("Product Name:", product_name)

        # Initialize quantity and price
        quantity = None
        price = None

        # Check the next row for quantity (single/double-digit integer)
        if i + 1 < len(text):
            next_item = text[i + 1]
            match_quantity = re.search(r"\b(\d{1,2})\b", next_item)

            if match_quantity:
                quantity = int(match_quantity.group())

        # Check the next three rows for the price (first float value)
        for j in range(i + 1, i + 4):
            if j < len(text):
                next_item = text[j]
                match_price = re.search(r"\b(\d+\.\d+)\b", next_item)

                if match_price:
                    price = float(match_price.group())
                    break  # Stop searching for price after the first match

        # Set default quantity as 1 if no value is found
        if quantity is None:
            quantity = 0

        # Add the data to the DataFrame
        df1.loc[len(df1)] = [bill_date, bill_no, product_name, quantity, price]

print(df1)
# Out:
# Bill Number: 501802014-012959
# Bill Date: 03/02/2023
# Product Name: Bi1l
# Product Name: AASHIR-1kg
# Product Name: NIVE-400ml
# Bill Number: 502001009-001074
# Bill Date: 05/01/2023
# Product Name: Cash1er
# Product Name: NUIRAJ FLAX SE-200g
# Product Name: FREE0O1 GROUNON-11t
# Product Name: GOLD OROP SUNFL-11t
# Product Name: PANTENE PR0-V-340ml
# Product Name: PRIL LIME N VING-3g
# Product Name: Bi1l
# Bill Date: 13/12/2022
# Product Name: AASHIRVAAD CHI 500g
# Product Name: AASHIRVAAD TUR 100g
# Product Name: NIVEA SKIN MI-400ml
# Product Name: COLGATE DENIAL-100g
# Product Name: PAIANJALI-REG 100g
# Product Name: NIVEA MEN DIL100g
# Product Name: VIM DISHNASH B125g
# Product Name: HIT RE0 COCKR-400ml
# Product Name: Shalkpet Tol1chowk
# Bill Date: 04/04/2023
# Bill Number: 501904020-000797
# Product Name: AS GRAND D FILI-11t
# Product Name: FREEDOM SUNFLO-51t
# Product Name: BAMBINO VERMI-1.4kg
# Product Name: KS SPARK DEO20ml
# Product Name: ANURAG DEEPARAD-11t
# ...

# %%
df1.to_csv('stores_bills.csv', index=False)

# %% [markdown]
# Validation/Accuracy calculation

# %%
image_folder = '/content/drive/MyDrive/SECONDARY DATA'
output_folder = '/content/Output_Invoices'  # Pat

# %%
os.makedirs(output_folder, exist_ok=True)

# %%
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpeg')]  # Add any other supported image formats as needed

# %%
from PIL import Image

# %%
pdf_path = os.path.join(output_folder, 'images.pdf')
pdf = Image.open(os.path.join(image_folder, image_files[0]))  # Open the first image file
pdf.save(pdf_path, "PDF", resolution=100.0, save_all=True, append_images=[Image.open(os.path.join(image_folder, image)) for image in image_files[1:]])

# %%
# !pip install Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 4.2 MB/s eta 0:00:00
# ...

# %%
#For calculating accuracy

import Levenshtein

# %%
file_path = "/content/Output_Invoices/images.pdf"  # Update the file path with the correct path and file extension

with open(file_path, 'r', encoding='latin-1') as f:
    reference = f.read().strip()

# %%
# assume that 'output' and 'reference' are lists of strings
output_str = ' '.join(text)
reference_str = ' '.join(reference)

# %%
# calculate word error rate (WER) and character error rate (CER)
wer = Levenshtein.distance(output_str.lower(), reference_str.lower()) / len(reference_str.split())
cer = Levenshtein.distance(output_str.lower(), reference_str.lower()) / len(reference_str.replace(' ', ''))

# %%
# print the WER and CER
print(f"Word Error Rate (WER): {wer}")
print(f"Character Error Rate (CER): {cer}")
# Out:
# Word Error Rate (WER): 2.102594650905366
# Character Error Rate (CER): 2.005998836143396

# %%
# DATA PUSH TO MySQL

# %%
print(df1)
# Out:
#      Bill_Date           Bill_No          Bill_Product  Bill_Quantity  Price
# 0   03/02/2023  501802014-012959                  Bi1l              0    NaN
# 1   03/02/2023  501802014-012959            AASHIR-1kg             26  26.32
# 2   03/02/2023  501802014-012959            NIVE-400ml              0  510.0
# 3   05/01/2023  502001009-001074               Cash1er              0   None
# 4   05/01/2023  502001009-001074   NUIRAJ FLAX SE-200g              1   55.0
# ..         ...               ...                   ...            ...    ...
# 76  06/01/2023  502001009-001341   PARLE HIDE N S-100g              3   27.0
# 77  06/01/2023  502001009-001341   VIM POWER 100L-500g              5   55.8
# 78  13/02/2023  502502012-002653               Cash1er              0   None
# 79  13/02/2023  502502012-002653   SURF EXCEL MAII-21t              2  399.0
# 80  13/02/2023  502502012-002653  Saved Rs. 162.00/-0a              0   None
#
# [81 rows x 5 columns]

# %%
# !pip install mysql-connector

# %%
import mysql.connector

# %%
# Establish a connection to the MySQL server
mydb = mysql.connector.connect(user='root', password='root', host='localhost')

# %%
# Create a cursor object
cursor = mydb.cursor()

# SQL query to create a new database
create_database_query = "CREATE DATABASE stores_data"

# Execute the query
cursor.execute(create_database_query)

# Close the cursor and the connection
cursor.close()
mydb.close()

# %%
# connect to mysql and puish data to sql
# Connection details
host = 'localhost'
database = 'stores_data'
user = 'root'
password = 'root'

# Create the MySQL connection string
engine = create_engine(f'mysql+mysqlconnector://{user}:{password}@{host}/{database}')


# Assuming `df` is your DataFrame
table_name = 'stores_bills'

# Push the DataFrame to the MySQL database
df1.to_sql(table_name, con=engine, if_exists='replace', index=False)

print('Data pushed to MySQL successfully.')

# %%
# !pip install pymysql

# %%
# Connection details
host = 'localhost'
port = 3306
user = 'root'
password = 'root'
database = 'stores_data'

# Create a MySQL connection string
connection_str = f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}'

# Create a database engine
engine = create_engine(connection_str)

# Convert the engine to a connection
connection = engine.connect()

table_name = 'stores_text'

# Query to retrieve data from a table
query = 'SELECT * FROM stores_text'

# Execute the query and fetch the data into a DataFrame
df = pd.read_sql(query, connection)

# Print the DataFrame
print(df)

# %% [markdown]
# DEPLOYMENT

# %%
# !pip install streamlit
import streamlit as st
import paddleocr
import re
import pandas as pd
from paddleocr import PaddleOCR, draw_ocr
import cv2
import numpy as np
ocr = PaddleOCR()
import os
from PIL import Image
# Out:
# ...
# [2024/01/09 10:50:59] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path=
# ...

# %%
def main():

    #logo_image = Image.open(r'C:/Users/sreep/OneDrive/Desktop/vlo/vlo.jpeg')
    #st.image(logo_image, width=400)

    st.title("Welcome To V-LO's Invoice Processing Tool")

    # Add an "Upload Images" section
    st.header("Upload your Invoice")
    uploaded_files = st.file_uploader("Choose a folder of images", type="jpeg", accept_multiple_files=True)

    if st.button("Process Invoice"):
        if uploaded_files:
            # Create a list to store the results
            results = []

            # Iterate over the uploaded files and process each image
            for file in uploaded_files:
                # Read the image using OpenCV
                image = cv2.imdecode(np.fromstring(file.read(), np.uint8), cv2.IMREAD_COLOR)

                # Perform OCR on the image using PaddleOCR
                result = ocr.ocr(image)

                # Store the result in the list
                results.append((file.name, result))

            # Process the stored results
            text = []
            for filename, result in results:
                #st.subheader(f"Text in {filename}:")
                for line in result:
                    for word in line:
                       # st.write(word[1][0])
                        text.append(word[1][0])
                    #st.write()
               # st.write()

            # Create a DataFrame to store the extracted information
            df1 = pd.DataFrame(columns=['Bill_Date', 'Bill_No', 'Bill_Product', 'Bill_Quantity', 'Unit_Price'])
            bill_no = None
            bill_date = None

            for i in range(len(text)):
                item = text[i]

                # Match bill number
                match_bill_no = re.search(r"\d{9}-\d{1,6}", item)
                if match_bill_no:
                    bill_no = match_bill_no.group()
                    #st.write("Bill Number:", bill_no)

                # Match bill date
                match_bill_date = re.search(r"\d{2}/\d{2}/\d{4}", item)
                if match_bill_date:
                    bill_date = match_bill_date.group()
                    #st.write("Bill Date:", bill_date)

                # Match product name
                match_product = re.search(
                    r"\s[A-Z]+\s[A-Z0-9]+\s[A-Z]+-\d[a-zA-Z]+|\s[A-Z]+\s[A-Z]+\s[A-Z]+-\d[a-zA-Z]+|[a-zA-Z]+[]\s\d+-[a-zA-Z]+\d[a-z]+|[a-aA-Z]+\s[a-zA-z]+\s+[a-zA-z]+\s\d+[a-zA-z]|[A-Z]+-\d+[a-zA-Z]|[A-z]+\s[A-Z]+-[a-zA-Z]+",
                    item)
                if match_product:
                    product_name = match_product.group()
                   # st.write("Product Name:", product_name)

                    # Initialize quantity and price
                    quantity = None
                    price = None

                    # Check the next row for quantity (single/double-digit integer)
                    if i + 1 < len(text):
                        next_item = text[i + 1]
                        match_quantity = re.search(r"\b(\d{1,2})\b", next_item)

                        if match_quantity:
                            quantity = int(match_quantity.group())

                        # Check the next three rows for the price (first float value)
                        for j in range(i + 1, i + 4):
                            if j < len(text):
                                next_item = text[j]
                                match_price = re.search(r"\b(\d+\.\d+)\b", next_item)

                                if match_price:
                                    price = float(match_price.group())
                                    break  # Stop searching for price after the first match

                    # Set default quantity as 1 if no value is found
                    if quantity is None:
                        quantity = 0

                    # Add the data to the DataFrame
                    df1.loc[len(df1)] = [bill_date, bill_no, product_name, quantity, price]

            # Display the extracted information in a table
            st.subheader("Extracted Information:")
            st.write(df1)
        else:
            st.warning("Please upload a folder of images.")

if __name__ == "__main__":
    # Load PaddleOCR
    ocr = PaddleOCR()

    # Run the Streamlit app
    main()
# Out:
# [2024/01/09 10:52:24] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path=
# ...

# %%
# !streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py --args "$@"
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: No such option: --args
